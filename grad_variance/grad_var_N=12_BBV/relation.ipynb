# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
corrcoef_list = []

for instance_id in range(20):
    grad_var = pd.read_csv(f"grad_var/{instance_id}.csv", header=None)
    grad_var = np.array(grad_var[0])
    weighted_degree = pd.read_csv(f"weighted_degree/{instance_id}.csv", header=None)
    weighted_degree = np.array(weighted_degree[0])
    corrcoef_list.append(np.corrcoef(grad_var, weighted_degree)[0][1])
    plt.scatter(grad_var, weighted_degree)  # 產生散佈圖
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.title("weighted degree relation with beta gradient variance of nodes")
    plt.show()
    print(f"correlation coefficient: {corrcoef_list[-1]}")
# Out:
# correlation coefficient: 0.9918945466053358
# correlation coefficient: 0.9772755308857026
# correlation coefficient: 0.974251529420336
# correlation coefficient: 0.9864184367728609
# correlation coefficient: 0.9737587106137886
# correlation coefficient: 0.9591357191403656
# correlation coefficient: 0.9971911693566771
# correlation coefficient: 0.9686915353226455
# correlation coefficient: 0.9858619145018674
# correlation coefficient: 0.9713603691019379
# correlation coefficient: 0.9664524581683078
# correlation coefficient: 0.8290531543673769
# correlation coefficient: 0.9940667301577776
# correlation coefficient: 0.9767541995670752
# correlation coefficient: 0.9839726384178359
# correlation coefficient: 0.9685302059991014
# correlation coefficient: 0.995981951817338
# correlation coefficient: 0.9367085718747317
# correlation coefficient: 0.9715654591108376
# correlation coefficient: 0.983078470089712

# %%
np.mean(corrcoef_list)
# Out:
# np.float64(0.9696001650645807)
