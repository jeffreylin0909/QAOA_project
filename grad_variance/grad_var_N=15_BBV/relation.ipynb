# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
corrcoef_list = []

for instance_id in range(20):
    grad_var = pd.read_csv(f"grad_var/{instance_id}.csv", header=None)
    grad_var = np.array(grad_var[0])
    weighted_degree = pd.read_csv(f"weighted_degree/{instance_id}.csv", header=None)
    weighted_degree = np.array(weighted_degree[0])
    corrcoef_list.append(np.corrcoef(grad_var, weighted_degree)[0][1])
    plt.scatter(grad_var, weighted_degree)  # 產生散佈圖
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.title("weighted degree relation with beta gradient variance of nodes")
    plt.show()
    print(f"correlation coefficient: {corrcoef_list[-1]}")
# Out:
# correlation coefficient: 0.979546282122759
# correlation coefficient: 0.9597052157286798
# correlation coefficient: 0.9884209601614454
# correlation coefficient: 0.9662826020608279
# correlation coefficient: 0.9696879767373751
# correlation coefficient: 0.9340550225349863
# correlation coefficient: 0.9907523699979441
# correlation coefficient: 0.9677144423887494
# correlation coefficient: 0.9601583676263005
# correlation coefficient: 0.9874441056828458
# correlation coefficient: 0.9747499537511339
# correlation coefficient: 0.9409217133404193
# correlation coefficient: 0.9770562350544325
# correlation coefficient: 0.9734816186048162
# correlation coefficient: 0.9754398521675858
# correlation coefficient: 0.9528024746479772
# correlation coefficient: 0.9865363138025637
# correlation coefficient: 0.9333440609074066
# correlation coefficient: 0.9675896199896227
# correlation coefficient: 0.9787095853984058

# %%
np.mean(corrcoef_list)
# Out:
# np.float64(0.9682199386353139)
