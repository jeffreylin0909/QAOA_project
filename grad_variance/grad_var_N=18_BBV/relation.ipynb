# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
corrcoef_list = []

for instance_id in range(20):
    grad_var = pd.read_csv(f"grad_var/{instance_id}.csv", header=None)
    grad_var = np.array(grad_var[0])
    weighted_degree = pd.read_csv(f"weighted_degree/{instance_id}.csv", header=None)
    weighted_degree = np.array(weighted_degree[0])
    corrcoef_list.append(np.corrcoef(grad_var, weighted_degree)[0][1])
    plt.scatter(grad_var, weighted_degree)  # 產生散佈圖
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.title("weighted degree relation with beta gradient variance of nodes")
    plt.show()
    print(f"correlation coefficient: {corrcoef_list[-1]}")
# Out:
# correlation coefficient: 0.9509628326081849
# correlation coefficient: 0.9563762886951604
# correlation coefficient: 0.9510699570020222
# correlation coefficient: 0.9371872484008105
# correlation coefficient: 0.9613077625296416
# correlation coefficient: 0.9214937061127091
# correlation coefficient: 0.9794243500296603
# correlation coefficient: 0.9686431509771372
# correlation coefficient: 0.9727499587957085
# correlation coefficient: 0.9736774584572241
# correlation coefficient: 0.9622549391301954
# correlation coefficient: 0.932739753087807
# correlation coefficient: 0.9616883165585051
# correlation coefficient: 0.9623231702196363
# correlation coefficient: 0.9610127389435709
# correlation coefficient: 0.94131234639542
# correlation coefficient: 0.963406522356268
# correlation coefficient: 0.9665400715951619
# correlation coefficient: 0.9678101737001501
# correlation coefficient: 0.9761546302834917

# %%
np.mean(corrcoef_list)
# Out:
# np.float64(0.9584067687939234)
